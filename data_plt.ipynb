# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('/mnt/f/python/file_data/broadcast.csv', index_col=0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
# 판다스에 내장된 선 그래프 그리기
df.plot()
# Out:
# <Axes: >

# %%
# 하나의 열만 선택
df.plot(y='KBS')
# Out:
# <Axes: >

# %%
# 여러개를 선택
df.plot(y=['KBS', 'JTBC'])
# Out:
# <Axes: >

# %%
df[['KBS', 'JTBC']]
# Out:
#          KBS   JTBC
# 2011  35.951  7.380
# 2012  36.163  7.878
# 2013  31.989  7.810
# 2014  31.210  7.490
# 2015  27.777  7.267
# 2016  27.583  7.727
# 2017  26.890  9.453

# %%
df[['KBS', 'JTBC']].plot()
# Out:
# <Axes: >

# %%
df['KBS']
# Out:
# 2011    35.951
# 2012    36.163
# 2013    31.989
# 2014    31.210
# 2015    27.777
# 2016    27.583
# 2017    26.890
# Name: KBS, dtype: float64

# %%
df['KBS'].plot()
# Out:
# <Axes: >

# %%
df = pd.read_csv('/mnt/f/python/file_data/sports.csv', index_col=0)
df
# Out:
#             Male  Female
# Swimming     103     178
# Baseball     363     289
# Basketball   151      97
# Golf         154     232
# Soccer       413     109
# Bowling       88     129

# %%
df.plot()
# Out:
# <Axes: >

# %%
# 막대그래프
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
# kind의 barh의 h는 horizontal(가로)의 약자다
df.plot(kind='barh')
# Out:
# <Axes: >

# %%
# stacked로 막대그래프를 합칠 수 있다
df.plot(kind='bar', stacked=True)
# Out:
# <Axes: >

# %%
df['Female']
# Out:
# Swimming      178
# Baseball      289
# Basketball     97
# Golf          232
# Soccer        109
# Bowling       129
# Name: Female, dtype: int64

# %%
df['Female'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df = pd.read_csv('a.csv')
df.head()
# Out:
#   job_category             race_ethnicity  gender   count  percentage
# 0  All workers                      White    Male  268883   41.257252
# 1  All workers                      White  Female  105560   16.197065
# 2  All workers  Black_or_African American    Male   17508    2.686417
# 3  All workers  Black_or_African American  Female   11479    1.761331
# 4  All workers                      Asian    Male  125347   19.233171

# %%
df[df['job_category'] == 'Managers']
# Out:
#    job_category             race_ethnicity  gender   count  percentage
# 22     Managers                      White    Male   48311   46.479253
# 23     Managers                      White  Female   18935   18.217065
# 24     Managers  Black_or_African American    Male    1575    1.515283
# 25     Managers  Black_or_African American  Female     978    0.940918
# 26     Managers                      Asian    Male   18563   17.859170
# 27     Managers                      Asian  Female    8084    7.777489
# 28     Managers         Hispanic_or_Latino    Male    3741    3.599157
# 29     Managers         Hispanic_or_Latino  Female    1642    1.579742
# 30     Managers                        All    Male   73526   70.738207
# 31     Managers                        All  Female   30415   29.261793
# 32     Managers                     Totals    Both  103941  100.000000

# %%
race_list = list(df.loc[df['job_category'] == 'Managers', 'race_ethnicity'].unique())
race_list
# Out:
# ['White',
#  'Black_or_African American',
#  'Asian',
#  'Hispanic_or_Latino',
#  'All',
#  'Totals']

# %%
df[((df['job_category'] == 'Managers') & (df['gender'] == 'Male') & (df['race_ethnicity'] != 'All'))].plot(kind='bar', x='race_ethnicity', y='count')
# Out:
# <Axes: xlabel='race_ethnicity'>

# %%
df = pd.read_csv('/mnt/f/python/file_data/broadcast.csv', index_col=0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
df.loc[2017].plot(kind='pie')
# Out:
# <Axes: ylabel='2017'>

# %%
df = pd.read_csv('silicon_valley_details.csv')
df
# Out:
#       company  year                race gender          job_category  count
# 0     23andMe  2016  Hispanic_or_Latino   male            Executives      0
# 1     23andMe  2016  Hispanic_or_Latino   male              Managers      1
# 2     23andMe  2016  Hispanic_or_Latino   male         Professionals      7
# 3     23andMe  2016  Hispanic_or_Latino   male           Technicians      0
# 4     23andMe  2016  Hispanic_or_Latino   male         Sales workers      0
# ...       ...   ...                 ...    ...                   ...    ...
# 4435  Sanmina  2016      Overall_totals    NaN  laborers and helpers      4
# 4436  Sanmina  2016      Overall_totals    NaN       Service workers     57
# 4437  Sanmina  2016      Overall_totals    NaN                Totals   5205
# 4438  Sanmina  2016      Overall_totals    NaN       Previous_totals   5615
# 4439  Sanmina  2016      Overall_totals    NaN              Managers    591
#
# [4440 rows x 6 columns]

# %%
df[(df['company'] == 'Adobe') & (df['count'] != 0)].value_counts('job_category').plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
con = (df['company'] == 'Adobe') & (df['count'] != 0) & (df['race'] == 'Overall_totals') & (df['job_category'] != 'Totals' )& (df['job_category'] != 'Previous_totals')
df.loc[con].set_index('job_category').plot(kind='pie', x='job_category', y='count')
# Out:
# <Axes: ylabel='count'>

# %%
df = pd.read_csv('/mnt/f/python/file_data/body.csv', index_col=0)
df
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# ...        ...     ...
# 996      171.8    68.2
# 997      171.5    75.6
# 998      177.9    66.5
# 999      174.4    72.0
# 1000     173.5    77.4
#
# [1000 rows x 2 columns]

# %%
# 히스토그램
df.plot(kind='hist', y='Height')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# bins = 구간 개수
df.plot(kind='hist', y='Height', bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df = pd.read_csv('/mnt/f/python/file_data/exam.csv', index_col=0)
df
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# female        group B           bachelor's degree      standard
# female        group C                some college      standard
# female        group B             master's degree      standard
# male          group A          associate's degree  free/reduced
# male          group C                some college      standard
# ...               ...                         ...           ...
# female        group E             master's degree      standard
# male          group C                 high school  free/reduced
# female        group C                 high school  free/reduced
# female        group D                some college      standard
# female        group D                some college  free/reduced
#
#        test preparation course  math score  reading score  writing score
# gender
# female                    none          72             72             74
# ...

# %%
# 박스플롯(박스그림)
# 최대값, 최소값, 중간값, 75%지점, 25% 지점 5개로 요약하여 나타냄

df['math score'].describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
df.plot(kind='box', y='math score')
# Out:
# <Axes: >

# %%
df.plot(kind='box', y=['math score', 'reading score', 'writing score'])
# Out:
# <Axes: >

# %%
# 산점도
# 상관관계를 보여주기 위해 사용

df.plot(kind='scatter', x='math score', y='reading score')
# Out:
# <Axes: xlabel='math score', ylabel='reading score'>

# %%
df.plot(kind='scatter', x='math score', y='writing score')
# Out:
# <Axes: xlabel='math score', ylabel='writing score'>

# %%
df.plot(kind='scatter', x='reading score', y='writing score')
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
df = pd.read_csv('/mnt/f/python/file_data/world_indexes.csv')
df.head()
# Out:
#             Id  Human Development Index HDI-2014  Gini coefficient 2005-2013  \
# 0       Norway                          0.943877                       26.83
# 1    Australia                          0.934958                       34.01
# 2  Switzerland                          0.929613                       32.35
# 3      Denmark                          0.923328                       26.88
# 4  Netherlands                          0.921794                       28.87
#
#    Adolescent birth rate 15-19 per 100k 20102015  \
# 0                                          7.834
# 1                                         12.059
# 2                                          1.900
# 3                                          5.101
# 4                                          6.165
#
#    Birth registration funder age 5 2005-2013  \
# 0                                      100.0
# 1                                      100.0
# 2                                      100.0
# ...

# %%
df.plot(kind='scatter', x='Life expectancy at birth- years', y='Internet users percentage of population 2014')
# Out:
# <Axes: xlabel='Life expectancy at birth- years', ylabel='Internet users percentage of population 2014'>

# %%
df.plot(kind='scatter', x='Forest area percentage of total land area 2012', y='Carbon dioxide emissionsAverage annual growth')
# Out:
# <Axes: xlabel='Forest area percentage of total land area 2012', ylabel='Carbon dioxide emissionsAverage annual growth'>

# %%
df.plot(kind='scatter', x='Internet users percentage of population 2014', y='Forest area percentage of total land area 2012', )
# Out:
# <Axes: xlabel='Internet users percentage of population 2014', ylabel='Forest area percentage of total land area 2012'>

# %%
df.plot(kind='scatter', x='Life expectancy at birth- years', y='Carbon dioxide emissionsAverage annual growth')
# Out:
# <Axes: xlabel='Life expectancy at birth- years', ylabel='Carbon dioxide emissionsAverage annual growth'>

# %%
df.plot(kind='scatter', x='Life expectancy at birth- years', y='Forest area percentage of total land area 2012')
# Out:
# <Axes: xlabel='Life expectancy at birth- years', ylabel='Forest area percentage of total land area 2012'>
