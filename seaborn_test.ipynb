# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.1-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.1-py3-none-any.whl (294 kB)
# ...

# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('/mnt/f/python/file_data/body.csv', index_col=0)
df.head()
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0

# %%
df['Height']
# Out:
# Number
# 1       176.0
# 2       175.3
# 3       168.6
# 4       168.1
# 5       175.3
#         ...
# 996     171.8
# 997     171.5
# 998     177.9
# 999     174.4
# 1000    173.5
# Name: Height, Length: 1000, dtype: float64

# %%
# 각 키가 몇 번 나오는지 확인
# index 순으로 정렬
df['Height'].value_counts().sort_index()
# Out:
# Height
# 154.4    1
# 155.5    1
# 157.4    1
# 157.8    1
# 158.0    1
#         ..
# 190.3    1
# 191.2    1
# 191.8    1
# 192.4    1
# 193.1    1
# Name: count, Length: 262, dtype: int64

# %%
df['Height'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='Height'>

# %%
# kde: 울퉁불퉁한 그래프를 매끄럽게 바꿔줌
# bw : 몇 개의 구간으로 나눌 것인가
sns.kdeplot(df['Height'], bw=0.5)
# Out:
# /tmp/ipykernel_1061/689699180.py:2: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   sns.kdeplot(df['Height'], bw=0.5)
# <Axes: xlabel='Height', ylabel='Density'>

# %%
df = pd.read_csv('./file_data/body.csv', index_col=0)
df.head()
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0

# %%
df.plot(kind='hist', y='Height', bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.distplot(df['Height'], bins=15)
# Out:
# /tmp/ipykernel_928/2479921645.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'], bins=15)
# <Axes: xlabel='Height', ylabel='Density'>

# %%
df.plot(kind='box', y='Height')
# Out:
# <Axes: >

# %%
sns.violinplot(y=df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
df.plot(kind='scatter', x='Height', y='Weight')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.kdeplot(x=df['Height'], y=df['Weight'])
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.kdeplot(df['Height'])
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.kdeplot(df['Weight'])
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
# 교수가 꿈인 지훈이는 교수들의 급여 분포를 알아보려고 합니다.
# 인터넷에서 어느 학교 교수의 급여 데이터를 발견했네요!
# 급여 ('salary')에 대한 Violin Plot을 그려 보세요.

# %matplotlib inline
import pandas as pd
import seaborn as sns

df = pd.read_csv('./file_data/salaries.csv')

sns.violinplot(df['salary'])
# Out:
# <Axes: ylabel='salary'>

# %%
df = pd.read_csv('./file_data/body.csv', index_col=0)
df.head()
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0

# %%
# 회귀선을 그려줌
sns.lmplot(data=df, x='Height', y='Weight')

# %%
df = pd.read_csv('./file_data/laptops.csv', index_col=0)
df.head()
# Out:
#                   model  ram hd_type  hd_size  screen_size   price  \
# brand
# Dell   Inspiron 15-3567    4     hdd     1024         15.6   40000
# Apple       MacBook Air    8     ssd      128         13.3   55499
# Apple       MacBook Air    8     ssd      256         13.3   71500
# Apple       MacBook Pro    8     ssd      128         13.3   96890
# Apple       MacBook Pro    8     ssd      256         13.3  112666
#
#       processor_brand processor_model  clock_speed graphic_card_brand  \
# brand
# Dell            intel              i5          2.5              intel
# Apple           intel              i5          1.8              intel
# Apple           intel              i5          1.8              intel
# Apple           intel              i5          2.3              intel
# Apple           intel              i5          2.3              intel
#
#        graphic_card_size     os  weight comments
# brand
# Dell                 NaN  linux    2.50      NaN
# ...

# %%
df['os'].unique()
# Out:
# array(['linux', 'mac', 'windows'], dtype=object)

# %%
sns.catplot(data=df, x='os', y='price', kind='violin')

# %%
sns.catplot(data=df, x='os', y='price', kind='strip')

# %%
df['processor_brand'].unique()
# Out:
# array(['intel', 'amd'], dtype=object)

# %%
# 브랜드 마다 색을 다르게 색칠해줌
sns.catplot(data=df, x='os', y='price', kind='strip', hue='processor_brand')
